# %% [markdown]
# # Introducción a Python - MATLAB

# %% [markdown]
# ### 2.2 Matemática Simple

# %%
4.0*0.15+4.5*0.35+3.0*0.4+4.8*0.1
# Out:
# 3.855

# %%
quices = 4.0
proyectos = 4.5
parciales = 3.0
tareas = 4.8

# %%
notadefinitiva = quices*0.15 + proyectos*0.35 + parciales*0.4 + tareas*0.1

print(notadefinitiva)
# Out:
# 3.855

# %%
parciales
# Out:
# 3.0

# %%
ejes = 4
rodamientos = 6
engranajes = 2

objetos = ejes + rodamientos + engranajes

# %%
objetos
# Out:
# 12

# %%
ejes = 6

# %%
ejes
# Out:
# 6

# %%
objetos
# Out:
# 12

# %% [markdown]
# ### 2.4 Arreglos

# %%
import numpy as np

# %%
x=np.array([0, 0.1*np.pi, 0.2*np.pi, 0.3*np.pi, 0.4*np.pi, 0.5*np.pi, 0.6*np.pi, 0.7*np.pi, 0.8*np.pi, 0.9*np.pi, np.pi])

# %%
y = np.sin(x)

# %%
x[2]
# Out:
# 0.62831853071795862

# %%
y[4]
# Out:
# 0.95105651629515353

# %%
x[:4]
# Out:
# array([ 0.        ,  0.31415927,  0.62831853,  0.9424778 ])

# %%
x[6:]
# Out:
# array([ 1.88495559,  2.19911486,  2.51327412,  2.82743339,  3.14159265])

# %%
x_2 = np.linspace(0,np.pi*2,100)
y_2 = np.sin(x_2)

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt

# %%
plt.plot(x_2,y_2)
plt.title("Función Seno")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 2.5 Álgebra Lineal

# %%
A = np.mat("1,2,3;4,5,6;7,8,0")
b = np.mat("366;804;351")

# %%
np.linalg.det(A)
# Out:
# 27.0

# %%
np.linalg.solve(A,b)
# Out:
# matrix([[ 25.],
#         [ 22.],
#         [ 99.]])
