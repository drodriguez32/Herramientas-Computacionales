# %%
import numpy as np
import cv2
import os

from scipy import ndimage
from skimage.measure import label, regionprops

# %pylab inline

output_dir = os.path.join('.')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
img = cv2.imread('200x_1010_T.tif') # importar la imagen
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY) # pasarla a escala de grises
ret,thresh = cv2.threshold(gray,0,1,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
#ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)

th2 = cv2.adaptiveThreshold(gray,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,21,15) # aplicar un threshold
th2 = ndimage.gaussian_filter(th2,3) # volverlo borroso con Gauss para eliminar el ruido
th2 = cv2.adaptiveThreshold(th2,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,21,5) # Volver a aplicar un threshold

#---------------------------
plt.subplot(131)
plt.imshow(img[:250,:500],cmap='gray')
plt.title('Original')

plt.subplot(132)
plt.imshow(thresh[:250,:500],cmap='gray')
plt.title('Threshold Original')

plt.subplot(133)
plt.imshow(th2[:250,:500],cmap='gray')
plt.title('Adaptive Threshold + Gauss')

plt.subplots_adjust(left=0.5, bottom=0.5, right = 2.5, top=5)

# %%
# noise removal
kernel = np.ones((3,3),np.uint8)
close = cv2.morphologyEx(th2,cv2.MORPH_CLOSE,kernel, iterations = 1)
opening = cv2.morphologyEx(th2,cv2.MORPH_OPEN,kernel, iterations = 4)
   #opening = thresh

# sure background area
   #sure_bg = cv2.dilate(opening,kernel,iterations=1)
sure_bg = opening

# Finding sure foreground area
  #dist_transform = cv2.distanceTransform(opening,cv2.DIST_L2,3)  # dist_transform es mejor para formas definidas como monedas
  #ret, sure_fg = cv2.threshold(dist_transform,0.7*dist_transform.max(),255,0)
sure_fg = cv2.erode(opening,kernel,iterations=1)

# Finding unknown region
sure_fg = np.uint8(sure_fg)
unknown = cv2.subtract(sure_bg,sure_fg)

#--------------------------

plt.subplot(121)
plt.imshow(opening[:250,:500],cmap='gray')
plt.title('Opening')

plt.subplot(122)
plt.imshow(thresh[:250,:500],cmap='gray')
plt.title('Original Threshold')

plt.subplots_adjust(left=0.5, bottom=0.5, right = 2.5, top=5)

# %%
plt.subplot(121)
plt.imshow(sure_fg[:250,:500],cmap='gray')
plt.title('Sure Foreground - White')

plt.subplot(122)
plt.imshow(sure_bg[:250,:500],cmap='gray')
plt.title('Sure Background - Black')

plt.subplots_adjust(left=0.5, bottom=0.5, right = 2.5, top=5)

# %%
# Marker labelling
ret, markers = cv2.connectedComponents(sure_fg)

# Add one to all labels so that sure background is not 0, but 1
markers = markers+1

# Now, mark the region of unknown with zero
markers[unknown==255] = 0

# %%
output = img.copy()

markers = cv2.watershed(img,markers) # apply watershed
output[markers == -1] = [255,0,0] # make the borders red

# %%
f, ax = plt.subplots(1, 2, figsize=(12, 5), sharey=True)

ax[0].imshow(img[:250,:500])
ax[0].set_title('Original')

ax[1].imshow(output[:250,:500])
ax[1].set_title('Watershed')

plt.tight_layout()


#pylab.savefig(os.path.join(output_dir,'prueba.png'), dpi=600)

# %%
test = np.zeros((gray.shape)) # create a black background
test[markers == -1] = 1 # superpose the markers with white color

plt.imshow(test[:100,:100],cmap='gray')
#pylab.savefig(os.path.join(output_dir,'prueba2.png'), dpi=1000)

# %%
label_img = label(test)
regions = regionprops(label_img) # Get region properties of the image

# %%
a = []  # Create empty list

for props in regions: # Go through all the regions
    a.append(props.area) # Get the area of the regions and add it to list
    
a = np.array(a) # Turn the list into an array
a.sort() # Sort it 
a = a[np.logical_and(a>=0,a<400)]  # Remove anything smaller than or greater than certain values

# %%
n, bins, patches = pyplot.hist(a,bins=50,rwidth = 0.6) # Create histogram with 50 bins, and column width = 0.6 of bin width

plt.grid()
plt.xticks(np.arange(0, 425, 25))
plt.xlabel('Area [px]')
plt.ylabel('Frecuencia')

rects = patches

# For each bar: Place a label
for rect in rects:
    # Get X and Y placement of label from rect.
    y_value = rect.get_height()
    x_value = rect.get_x() + rect.get_width() / 2

    # Number of points between bar and label. Change to your liking.
    space = 5
    # Vertical alignment for positive values
    va = 'bottom'

    # If value of bar is negative: Place label below bar
    if y_value < 0:
        # Invert space to place label below
        space *= -1
        # Vertically align label at top
        va = 'top'

    # Use Y value as label and format number with one decimal place
    label = "{:.1f}".format(x_value)

    # Create annotation
    plt.annotate(
        label,                      # Use `label` as label
        (x_value, y_value),         # Place label at end of the bar
        xytext=(0, space),          # Vertically shift label by `space`
        textcoords="offset points", # Interpret `xytext` as offset in points
        ha='center',                # Horizontally center label
        va=va)                      # Vertically align label differently for
                                    # positive and negative values.

plt.subplots_adjust(left=0, bottom=0, right = 4, top=3)

# %%
patches[0].get_height()
# Out:
# 160.0
